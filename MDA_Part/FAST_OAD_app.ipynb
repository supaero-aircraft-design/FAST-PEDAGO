# %%
import ipywidgets as widgets
from IPython.display import display
from Interface import Interface
Interface().__init__()
Interface().Menu()
# Out:
# ...
# <div>                            <div id="5ace1190-08e6-4ba3-95f5-78bc59431f64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ace1190-08e6-4ba3-95f5-78bc59431f64")) {                    Plotly.newPlot(                        "5ace1190-08e6-4ba3-95f5-78bc59431f64",                        [{"mode":"lines+markers","name":"V stall","type":"scatter","uid":"2b010518-5199-4ef3-8398-d15ebfe9eaae","x":[8792.277332500567,8792.277332500567],"y":[0,20]},{"mode":"lines+markers","name":"Take Off","type":"scatter","uid":"b77ce8a0-4901-4fa4-a961-cc01a3efe54f","x":[0.0,90.9090909090909,181.8181818181818,272.72727272727275,363.6363636363636,454.5454545454545,545.4545454545455,636.3636363636364,727.2727272727273,818.1818181818181,909.090909090909,1000.0,1090.909090
# ...
